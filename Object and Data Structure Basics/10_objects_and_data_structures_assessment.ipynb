# %% [markdown]
# # 10 - Objects and Data Structures Assessment
#
# A concise practice notebook with real-world examples and visible printed answers.

# %% [markdown]
# ## Assessment practice
# Each task includes an answer cell with printed output.

# %% [markdown]
# ### Task 1
# Calculate `50 + 50` and `100 - 10`.

# %%
print(50 + 50)
print(100 - 10)
# Out:
# 100
# 90

# %% [markdown]
# ### Task 2
# Create a string and print the first, middle, and last character.

# %%
word = "delivery"

print(word[0])
print(word[3])
print(word[-1])
# Out:
# d
# i
# y

# %% [markdown]
# ### Task 3
# Build a list of three cities, add one city, then print the final list.

# %%
cities = ["Dallas", "Denver", "Seattle"]
cities.append("Miami")

print(cities)
# Out:
# ['Dallas', 'Denver', 'Seattle', 'Miami']

# %% [markdown]
# ### Task 4
# Use a dictionary to store a product name, price, and stock count.

# %%
product = {
    "name": "backpack",
    "price": 48.99,
    "stock": 15
}

print(product)
print(product["name"])
print(product["price"])
# Out:
# {'name': 'backpack', 'price': 48.99, 'stock': 15}
# backpack
# 48.99

# %% [markdown]
# ### Task 5
# Use a set to remove duplicate names.

# %%
names = ["Mia", "Noah", "Mia", "Liam", "Noah"]
unique_names = set(names)

print(unique_names)
# Out:
# {'Liam', 'Mia', 'Noah'}

# %% [markdown]
# ### Task 6
# Use booleans to check whether a customer qualifies for free shipping.

# %%
cart_total = 65
free_shipping_threshold = 50

qualifies = cart_total >= free_shipping_threshold
print(qualifies)
# Out:
# True

# %% [markdown]
# ### Task 7
# Write a short note to a file and read it back.

# %%
with open("reminder.txt", "w") as file:
    file.write("Submit project by Friday.")

with open("reminder.txt", "r") as file:
    print(file.read())
# Out:
# Submit project by Friday.
