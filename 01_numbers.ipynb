# %% [markdown]
# # 01 - Numbers
#
# These notes are an original beginner-friendly practice notebook for Python object and data structure basics.

# %% [markdown]
# ## Integers and floats
# Python can work with whole numbers and decimal values.

# %%
10 + 5

# %%
12 - 4

# %%
6 * 7

# %%
20 / 4

# %% [markdown]
# Division with `/` returns a float. Floor division `//` keeps only the whole-number part.

# %%
17 / 3

# %%
17 // 3

# %%
17 % 3  # remainder

# %% [markdown]
# ## Powers

# %%
2 ** 5

# %% [markdown]
# ## Order of operations

# %%
(2 + 3) * 4

# %%
2 + 3 * 4

# %% [markdown]
# ## Practice

# %%
# Calculate the total cost of 3 notebooks at $2.75 each
price = 2.75
quantity = 3
total = price * quantity
total
